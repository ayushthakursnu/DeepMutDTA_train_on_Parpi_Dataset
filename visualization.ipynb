# %%
import pandas as pd

# %%
df = pd.read_csv("results_aggregate.csv")
df
# Out:
#    seed  best_epoch  val_accuracy  val_specificity  val_recall   val_auc
# 0     4        14.0      0.810928         0.876884    0.663866  0.865761  \
# 1     0         5.0      0.803122         0.869347    0.655462  0.853895
# 2     3        17.0      0.803122         0.894472    0.599440  0.862050
# 3     1        15.0      0.802255         0.914573    0.551821  0.866482
# 4     2        12.0      0.800520         0.876884    0.630252  0.860247
# 5  mean         NaN      0.803990         0.886432    0.620168  0.861687
# 6   std         NaN      0.004022         0.018240    0.045711  0.005063
#
#    val_aupr   val_pcc   val_scc  test_accuracy  test_specificity  test_recall
# 0  0.726348  0.608681  0.585800       0.779029          0.857875     0.613941  \
# 1  0.709503  0.582389  0.566795       0.801560          0.871959     0.654155
# 2  0.728045  0.585451  0.579857       0.794627          0.888604     0.597855
# ...
